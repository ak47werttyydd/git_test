# %%
from guided_test import GuideTestingGA
import torch
import numpy as np

# %%
from abc import ABCMeta, abstractmethod
from typing import Sequence
import torch
import numpy as np
import os
import tvm
import time

import pygad
import graph_generator.op_constraint as opc
import graph_generator.guided_cell_generation as gcg
from sequence_generator.pass_analysis_util import get_all_passes_tvm
import sequence_generator.config as sg_config
import graph_generator.config as gg_config
from graph_generator.graph_debug import test_under_pytorch

class GuideTesting(metaclass=ABCMeta):
    def __init__(self):
        pass
    
    @abstractmethod
    def sample_graph(self):
        pass
    
    @abstractmethod
    def sample_sequence(self):
        pass

class GuideTestingGA(GuideTesting):
    def __init__(self, 
                 graph_table_path, 
                 seq_path,
                 alpha=100,
                 beta=0.1,
                 max_batch_size=16,
                 input_shapes=gg_config.input_shapes,
                 output_shapes=gg_config.output_shapes,
                 graph_store_prefix="graph_generator",
                 output_class=1000):
        super(GuideTestingGA, self).__init__()
        self.max_sample_sub_graphs = None
        self.cell_table_path = graph_table_path
        self.seq_path = seq_path
        self.cluster_lookup = torch.load(graph_table_path)
        self.sequence_lookup = torch.load(seq_path)
        self.input_shapes = input_shapes
        self.output_shapes = output_shapes
        self.output_class = output_class
        self.graph_store_prefix = graph_store_prefix
        self.alpha = alpha
        self.beta = beta
        self.max_batch_size = max_batch_size
        self.sequence_pool_length = len(self.sequence_lookup)
        self._sort_sub_graphs_table()
        self._sort_sequence()
        self.shape_str_list = list()
        self._process_shape()
        self.recorder = list()
        self.count = 0
    
    def _process_shape(self):
        for idx in range(len(self.input_shapes)):
            in_shape_str = "_".join(str(i) for i in self.input_shapes[idx][1:])
            out_shape_str = "_".join(str(i) for i in self.output_shapes[idx][1:])
            self.shape_str_list.append(in_shape_str + "_" + out_shape_str)

    def _sort_sub_graphs_table(self):
        for key in self.cluster_lookup:
            new_list = []
            for item in self.cluster_lookup[key]:
                location = os.path.join(self.graph_store_prefix, item[2:])
                new_list.append((item, gcg.load_onnx_graph(location).ByteSize()))
            new_list = sorted(new_list, key=lambda x:x[1])
            new_list = [i[0] for i in new_list]
            self.cluster_lookup[key] = new_list
        self.max_sample_sub_graphs = len(new_list)
    
    def _sort_sequence(self):
        pass_opt_level_lookup = get_all_passes_tvm()
        test_passes = sg_config.test_passes
        str_sequence = [test_passes[i] for i in self.sequence_lookup]
        order_sequence_list = list()
        for seq in str_sequence:
            seq_weight = 0
            for opt_pass in seq:
                if opt_pass == "CombineParallelConv2D":
                    opt_pass = "CombineParallelConv2d"
                elif opt_pass == "Inline":
                    opt_pass = "InlineGlobals"
                seq_weight += pass_opt_level_lookup[opt_pass]['opt_level']
            order_sequence_list.append([seq, seq_weight])
        order_sequence_list = sorted(order_sequence_list, key=lambda x:x[1])
        sequence = [i[0] for i in order_sequence_list]
        self.sequence_lookup = sequence
        
    def sample_graph(self, cell_idx_list):
        #
        sub_graphs = list()
        for cell_number, idx in enumerate(cell_idx_list):
            shape = self.shape_str_list[cell_number]
            graph_path = self.cluster_lookup[shape][idx][4:]
            graph_path = os.path.join(self.graph_store_prefix, graph_path)
            graph_path = graph_path.replace("onnx", "pt")
            graph = torch.load(graph_path)
            sub_graphs.append(graph)
        otuput_layer = opc.OutputLayer(self.output_shapes[-1], self.output_class)
        sub_graphs.append(otuput_layer)
        combined_model = torch.nn.Sequential(*sub_graphs)
        combined_model = combined_model.eval()
        return combined_model
    
    def sample_sequence(self, idx):
        seq = self.sequence_lookup[idx]
        temp_list = list()
        for i in seq:
            temp_list.append(getattr(tvm.relay.transform, i)())
        temp_list = tvm.transform.Sequential(temp_list)
        return temp_list
    
    def _test_graph(self, choices):
        batch_size = choices[0]
        input_shape = self.input_shapes[0]
        input_shape[0] = batch_size
        input = torch.randn(input_shape)
        sub_graph_choice = choices[1:4]
        graph = self.sample_graph(sub_graph_choice)
        opt_seq = self.sample_sequence(choices[-1])
        result = test_under_pytorch(graph, input, custom_opt_passes=opt_seq)
        return result
    
    def get_on_generation_function(self):
        def on_generation_function(GA_instance):
            if max(GA_instance.last_generation_fitness) == np.inf:
                return "stop"
        return on_generation_function
    
    def record_error(self, solution):
        self.max_sample_sub_graphs -= 1
        self.sequence_pool_length -= 1
        sequence_idx = solution[0]
        self.sequence_lookup.pop(sequence_idx)
        cell_idx_list = solution[1:-1]
        for cell_number, idx in enumerate(cell_idx_list):
            self.cluster_lookup[self.shape_str_list[cell_number]].pop(idx)
            
    def get_fitness_function(self):
        def fitness_function(solution, solution_idx):
            start_time = time.time()
            result = self._test_graph(solution)
            end_time = time.time()
            self.count += 1
            if result[0] == False:
                # Find bug
                #print(result[1])
                self.recorder.append([solution, result])
                self.record_error(solution)
                score = np.inf
            else:
                output = result[-1]
                max_inf_norm = -1
                for idx in range(len(output['pytorch'])):
                    result_pytorch = output['pytorch'][idx].reshape(-1)
                    result_tvm = output['tvm'][idx].reshape(-1)
                    inf_norm = torch.linalg.norm(torch.tensor(result_pytorch) - torch.tensor(result_tvm), ord=np.inf)
                    if inf_norm > max_inf_norm:
                        max_inf_norm = inf_norm
                score = self.alpha * max_inf_norm + self.beta * (end_time - start_time)
            return score
        return fitness_function
    
    def guide_test(self, limit_time):
        start_time = time.time()
        while(True):
            period_end_time = time.time()
            if (period_end_time - start_time) > limit_time:
                break
            fitness_function = self.get_fitness_function()
            on_generation_function = self.get_on_generation_function()
            ga_instance = pygad.GA(num_generations=100,
                                    num_parents_mating=2,
                                    sol_per_pop=2,
                                    num_genes=5,
                                    mutation_percent_genes=20,
                                    fitness_func=fitness_function,
                                    mutation_by_replacement=True,
                                    on_generation=on_generation_function,
                                    gene_type=int,
                                    gene_space=[[i for i in range(self.max_batch_size)],
                                                [i for i in range(self.max_sample_sub_graphs)],
                                                [i for i in range(self.max_sample_sub_graphs)],
                                                [i for i in range(self.max_sample_sub_graphs)],
                                                [i for i in range(self.sequence_pool_length)]]
                                    )
            ga_instance.run()

# %%
test_tool = GuideTestingGA(
    graph_table_path = "graph_generator/cell/cluster_location.pt",
    seq_path = "sequence_generator/seq/GA_sequence.pt"
)

# %%
test_tool.guide_test(60)
# Out:
# /home/yuheng/anaconda3/lib/python3.9/site-packages/torch/nn/functional.py:2359: UserWarning: __floordiv__ is deprecated, and its behavior will change in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values. To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor').
#   _verify_batch_size([input.size(0) * input.size(1) // num_groups, num_groups] + list(input.size()[2:]))
# For x86 target, depthwise_conv2d with channel multiplier greater than 1 is not optimized
# For x86 target, depthwise_conv2d with channel multiplier greater than 1 is not optimized
# For x86 target, depthwise_conv2d with channel multiplier greater than 1 is not optimized
# For x86 target, depthwise_conv2d with channel multiplier greater than 1 is not optimized

# %%
len(test_tool.recorder)
# Out:
# 0

# %%
test_tool.recorder[0][0]
# Out:
# array([  1, 248, 230, 290,  34])

# %%
test_tool.recorder[1][0]
# Out:
# array([  6, 259,  15, 193, 113])

# %%
test_tool.max_sample_sub_graphs
# Out:
# 299

# %%
test_tool.sequence_pool_length
# Out:
# 499

# %%
test_tool.count
# Out:
# 4

# %%
80s --> 4
20s --> 1
300

# %%
temp = torch.load("guided_test.pt")

# %%
count = 0
for i in temp.recorder:
    if i[0][0] > 0:
        count += 1
        print(i[1][1])
# Out:
# Traceback (most recent call last):
#   255: TVMFuncCall
#         at /home/yuheng/tvm/src/runtime/c_runtime_api.cc:474
#   254: tvm::runtime::PackedFunc::CallPacked(tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*) const
#         at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1151
#   253: std::function<void (tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*)>::operator()(tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*) const
#         at /usr/bin/../lib/gcc/x86_64-linux-gnu/9/../../../../include/c++/9/bits/std_function.h:688
#   252: std::_Function_handler<void (tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*), tvm::relay::backend::RelayBuildModule::GetFunction(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, tvm::runtime::ObjectPtr<tvm::runtime::Object> const&)::{lambda(tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*)#3}>::_M_invoke(std::_Any_data const&, tvm::runtime::TVMArgs&&, tvm::runtime::TVMRetValue*&&)
#         at /usr/bin/../lib/gcc/x86_64-linux-gnu/9/../../../../include/c++/9/bits/std_function.h:300
#   251: tvm::relay::backend::RelayBuildModule::GetFunction(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, tvm::runtime::ObjectPtr<tvm::runtime::Object> const&)::{lambda(tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*)#3}::operator()(tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*) const
#         at /home/yuheng/tvm/src/relay/backend/build_module.cc:190
#   250: tvm::relay::backend::RelayBuildModule::Build(tvm::IRModule, tvm::runtime::Map<tvm::Integer, tvm::Target, void, void> const&, tvm::Target const&, tvm::relay::Executor const&, tvm::relay::Runtime const&, tvm::runtime::String)
#         at /home/yuheng/tvm/src/relay/backend/build_module.cc:303
#   249: tvm::relay::backend::RelayBuildModule::BuildRelay(tvm::IRModule, tvm::runtime::String const&)
#         at /home/yuheng/tvm/src/relay/backend/build_module.cc:415
#   248: tvm::relay::backend::ExecutorCodegen::Codegen(tvm::IRModule, tvm::relay::Function const&, tvm::runtime::String)
#         at /home/yuheng/tvm/src/relay/backend/build_module.cc:65
#   247: void tvm::relay::backend::ExecutorCodegen::CallFunc<tvm::IRModule, tvm::relay::Function, tvm::runtime::String>(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, tvm::IRModule, tvm::relay::Function, tvm::runtime::String)
#         at /home/yuheng/tvm/src/relay/backend/build_module.cc:119
#   246: tvm::runtime::TVMRetValue tvm::runtime::PackedFunc::operator()<tvm::IRModule, tvm::relay::Function, tvm::runtime::String>(tvm::IRModule&&, tvm::relay::Function&&, tvm::runtime::String&&) const
#         at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1369
#   245: std::function<void (tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*)>::operator()(tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*) const
#         at /usr/bin/../lib/gcc/x86_64-linux-gnu/9/../../../../include/c++/9/bits/std_function.h:688
#   244: std::_Function_handler<void (tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*), tvm::relay::backend::GraphExecutorCodegenModule::GetFunction(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, tvm::runtime::ObjectPtr<tvm::runtime::Object> const&)::{lambda(tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*)#2}>::_M_invoke(std::_Any_data const&, tvm::runtime::TVMArgs&&, tvm::runtime::TVMRetValue*&&)
#         at /usr/bin/../lib/gcc/x86_64-linux-gnu/9/../../../../include/c++/9/bits/std_function.h:300
#   243: tvm::relay::backend::GraphExecutorCodegenModule::GetFunction(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, tvm::runtime::ObjectPtr<tvm::runtime::Object> const&)::{lambda(tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*)#2}::operator()(tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*) const
#         at /home/yuheng/tvm/src/relay/backend/graph_executor_codegen.cc:661
#   242: tvm::relay::backend::GraphExecutorCodegen::Codegen(tvm::IRModule, tvm::relay::Function, tvm::runtime::String)
#         at /home/yuheng/tvm/src/relay/backend/graph_executor_codegen.cc:233
#   241: tvm::transform::Pass::operator()(tvm::IRModule) const
#         at /home/yuheng/tvm/src/ir/transform.cc:255
#   240: tvm::transform::Pass::operator()(tvm::IRModule, tvm::transform::PassContext const&) const
#         at /home/yuheng/tvm/src/ir/transform.cc:267
#   239: tvm::transform::SequentialNode::operator()(tvm::IRModule, tvm::transform::PassContext const&) const
#         at /home/yuheng/tvm/src/ir/transform.cc:487
#   238: tvm::transform::Pass::operator()(tvm::IRModule, tvm::transform::PassContext const&) const
#         at /home/yuheng/tvm/src/ir/transform.cc:267
#   237: tvm::transform::ModulePassNode::operator()(tvm::IRModule, tvm::transform::PassContext const&) const
#         at /home/yuheng/tvm/src/ir/transform.cc:416
#   236: tvm::runtime::TypedPackedFunc<tvm::IRModule (tvm::IRModule, tvm::transform::PassContext)>::operator()(tvm::IRModule, tvm::transform::PassContext) const
#         at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1498
#   235: tvm::IRModule tvm::runtime::detail::typed_packed_call_dispatcher<tvm::IRModule>::run<tvm::IRModule, tvm::transform::PassContext>(tvm::runtime::PackedFunc const&, tvm::IRModule&&, tvm::transform::PassContext&&)
#         at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1444
#   234: tvm::runtime::TVMRetValue tvm::runtime::PackedFunc::operator()<tvm::IRModule, tvm::transform::PassContext>(tvm::IRModule&&, tvm::transform::PassContext&&) const
#         at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1369
#   233: std::function<void (tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*)>::operator()(tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*) const
#         at /usr/bin/../lib/gcc/x86_64-linux-gnu/9/../../../../include/c++/9/bits/std_function.h:688
#   232: std::_Function_handler<void (tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*), tvm::runtime::TypedPackedFunc<tvm::IRModule (tvm::IRModule, tvm::transform::PassContext)>::AssignTypedLambda<tvm::relay::tec::LowerTEPass(tvm::runtime::String const&, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_8>(tvm::relay::tec::LowerTEPass(tvm::runtime::String const&, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_8)::{lambda(tvm::runtime::TVMArgs const&, tvm::runtime::TVMRetValue*)#1}>::_M_invoke(std::_Any_data const&, tvm::runtime::TVMArgs&&, tvm::runtime::TVMRetValue*&&)
#         at /usr/bin/../lib/gcc/x86_64-linux-gnu/9/../../../../include/c++/9/bits/std_function.h:300
#   231: tvm::runtime::TypedPackedFunc<tvm::IRModule (tvm::IRModule, tvm::transform::PassContext)>::AssignTypedLambda<tvm::relay::tec::LowerTEPass(tvm::runtime::String const&, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_8>(tvm::relay::tec::LowerTEPass(tvm::runtime::String const&, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_8)::{lambda(tvm::runtime::TVMArgs const&, tvm::runtime::TVMRetValue*)#1}::operator()(tvm::runtime::TVMArgs const&, tvm::runtime::TVMRetValue*) const
#         at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1492
#   230: void tvm::runtime::detail::unpack_call<tvm::IRModule, 2, tvm::relay::tec::LowerTEPass(tvm::runtime::String const&, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_8>(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const*, tvm::relay::tec::LowerTEPass(tvm::runtime::String const&, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_8 const&, tvm::runtime::TVMArgs const&, tvm::runtime::TVMRetValue*)
#         at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1421
#   229: void tvm::runtime::detail::unpack_call_dispatcher<tvm::IRModule, 2, 0, tvm::relay::tec::LowerTEPass(tvm::runtime::String const&, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_8>::run<>(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const*, tvm::relay::tec::LowerTEPass(tvm::runtime::String const&, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_8 const&, tvm::runtime::TVMArgs const&, tvm::runtime::TVMRetValue*)
#         at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1382
#   228: void tvm::runtime::detail::unpack_call_dispatcher<tvm::IRModule, 1, 1, tvm::relay::tec::LowerTEPass(tvm::runtime::String const&, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_8>::run<tvm::runtime::TVMMovableArgValueWithContext_>(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const*, tvm::relay::tec::LowerTEPass(tvm::runtime::String const&, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_8 const&, tvm::runtime::TVMArgs const&, tvm::runtime::TVMRetValue*, tvm::runtime::TVMMovableArgValueWithContext_&&)
#         at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1382
#   227: void tvm::runtime::detail::unpack_call_dispatcher<tvm::IRModule, 0, 2, tvm::relay::tec::LowerTEPass(tvm::runtime::String const&, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_8>::run<tvm::runtime::TVMMovableArgValueWithContext_, tvm::runtime::TVMMovableArgValueWithContext_>(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const*, tvm::relay::tec::LowerTEPass(tvm::runtime::String const&, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_8 const&, tvm::runtime::TVMArgs const&, tvm::runtime::TVMRetValue*, tvm::runtime::TVMMovableArgValueWithContext_&&, tvm::runtime::TVMMovableArgValueWithContext_&&)
#         at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1397
#   226: tvm::relay::tec::LowerTEPass(tvm::runtime::String const&, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_8::operator()(tvm::IRModule, tvm::transform::PassContext) const
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:1167
#   225: tvm::relay::tec::LowerTE(tvm::IRModule const&, tvm::runtime::String const&, std::function<void (tvm::BaseFunc)>, tvm::SEScope)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:1063
#   224: tvm::transform::Pass::operator()(tvm::IRModule) const
#         at /home/yuheng/tvm/src/ir/transform.cc:255
#   223: tvm::transform::Pass::operator()(tvm::IRModule, tvm::transform::PassContext const&) const
#         at /home/yuheng/tvm/src/ir/transform.cc:267
#   222: tvm::relay::transform::FunctionPassNode::operator()(tvm::IRModule, tvm::transform::PassContext const&) const
#         at /home/yuheng/tvm/src/relay/ir/transform.cc:133
#   221: tvm::runtime::TypedPackedFunc<tvm::relay::Function (tvm::relay::Function, tvm::IRModule, tvm::transform::PassContext)>::operator()(tvm::relay::Function, tvm::IRModule, tvm::transform::PassContext) const
#         at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1498
#   220: tvm::relay::Function tvm::runtime::detail::typed_packed_call_dispatcher<tvm::relay::Function>::run<tvm::relay::Function, tvm::IRModule, tvm::transform::PassContext>(tvm::runtime::PackedFunc const&, tvm::relay::Function&&, tvm::IRModule&&, tvm::transform::PassContext&&)
#         at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1444
#   219: tvm::runtime::TVMRetValue tvm::runtime::PackedFunc::operator()<tvm::relay::Function, tvm::IRModule, tvm::transform::PassContext>(tvm::relay::Function&&, tvm::IRModule&&, tvm::transform::PassContext&&) const
#         at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1369
#   218: std::function<void (tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*)>::operator()(tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*) const
#         at /usr/bin/../lib/gcc/x86_64-linux-gnu/9/../../../../include/c++/9/bits/std_function.h:688
#   217: std::_Function_handler<void (tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*), tvm::runtime::TypedPackedFunc<tvm::relay::Function (tvm::relay::Function, tvm::IRModule, tvm::transform::PassContext)>::AssignTypedLambda<tvm::relay::tec::LowerTensorExpr(tvm::runtime::String const&, tvm::relay::tec::TECompiler, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_7>(tvm::relay::tec::LowerTensorExpr(tvm::runtime::String const&, tvm::relay::tec::TECompiler, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_7)::{lambda(tvm::runtime::TVMArgs const&, tvm::runtime::TVMRetValue*)#1}>::_M_invoke(std::_Any_data const&, tvm::runtime::TVMArgs&&, tvm::runtime::TVMRetValue*&&)
#         at /usr/bin/../lib/gcc/x86_64-linux-gnu/9/../../../../include/c++/9/bits/std_function.h:300
#   216: tvm::runtime::TypedPackedFunc<tvm::relay::Function (tvm::relay::Function, tvm::IRModule, tvm::transform::PassContext)>::AssignTypedLambda<tvm::relay::tec::LowerTensorExpr(tvm::runtime::String const&, tvm::relay::tec::TECompiler, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_7>(tvm::relay::tec::LowerTensorExpr(tvm::runtime::String const&, tvm::relay::tec::TECompiler, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_7)::{lambda(tvm::runtime::TVMArgs const&, tvm::runtime::TVMRetValue*)#1}::operator()(tvm::runtime::TVMArgs const&, tvm::runtime::TVMRetValue*) const
#         at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1492
#   215: void tvm::runtime::detail::unpack_call<tvm::relay::Function, 3, tvm::relay::tec::LowerTensorExpr(tvm::runtime::String const&, tvm::relay::tec::TECompiler, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_7>(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const*, tvm::relay::tec::LowerTensorExpr(tvm::runtime::String const&, tvm::relay::tec::TECompiler, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_7 const&, tvm::runtime::TVMArgs const&, tvm::runtime::TVMRetValue*)
#         at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1421
#   214: void tvm::runtime::detail::unpack_call_dispatcher<tvm::relay::Function, 3, 0, tvm::relay::tec::LowerTensorExpr(tvm::runtime::String const&, tvm::relay::tec::TECompiler, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_7>::run<>(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const*, tvm::relay::tec::LowerTensorExpr(tvm::runtime::String const&, tvm::relay::tec::TECompiler, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_7 const&, tvm::runtime::TVMArgs const&, tvm::runtime::TVMRetValue*)
#         at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1382
#   213: void tvm::runtime::detail::unpack_call_dispatcher<tvm::relay::Function, 2, 1, tvm::relay::tec::LowerTensorExpr(tvm::runtime::String const&, tvm::relay::tec::TECompiler, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_7>::run<tvm::runtime::TVMMovableArgValueWithContext_>(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const*, tvm::relay::tec::LowerTensorExpr(tvm::runtime::String const&, tvm::relay::tec::TECompiler, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_7 const&, tvm::runtime::TVMArgs const&, tvm::runtime::TVMRetValue*, tvm::runtime::TVMMovableArgValueWithContext_&&)
#         at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1382
#   212: void tvm::runtime::detail::unpack_call_dispatcher<tvm::relay::Function, 1, 2, tvm::relay::tec::LowerTensorExpr(tvm::runtime::String const&, tvm::relay::tec::TECompiler, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_7>::run<tvm::runtime::TVMMovableArgValueWithContext_, tvm::runtime::TVMMovableArgValueWithContext_>(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const*, tvm::relay::tec::LowerTensorExpr(tvm::runtime::String const&, tvm::relay::tec::TECompiler, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_7 const&, tvm::runtime::TVMArgs const&, tvm::runtime::TVMRetValue*, tvm::runtime::TVMMovableArgValueWithContext_&&, tvm::runtime::TVMMovableArgValueWithContext_&&)
#         at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1382
#   211: void tvm::runtime::detail::unpack_call_dispatcher<tvm::relay::Function, 0, 3, tvm::relay::tec::LowerTensorExpr(tvm::runtime::String const&, tvm::relay::tec::TECompiler, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_7>::run<tvm::runtime::TVMMovableArgValueWithContext_, tvm::runtime::TVMMovableArgValueWithContext_, tvm::runtime::TVMMovableArgValueWithContext_>(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const*, tvm::relay::tec::LowerTensorExpr(tvm::runtime::String const&, tvm::relay::tec::TECompiler, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_7 const&, tvm::runtime::TVMArgs const&, tvm::runtime::TVMRetValue*, tvm::runtime::TVMMovableArgValueWithContext_&&, tvm::runtime::TVMMovableArgValueWithContext_&&, tvm::runtime::TVMMovableArgValueWithContext_&&)
#         at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1397
#   210: tvm::relay::tec::LowerTensorExpr(tvm::runtime::String const&, tvm::relay::tec::TECompiler, std::function<void (tvm::BaseFunc)>, tvm::SEScope)::$_7::operator()(tvm::relay::Function, tvm::IRModule, tvm::transform::PassContext) const
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:815
#   209: tvm::relay::ExprMutator::Mutate(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:190
#   208: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   207: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   206: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   205: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#5}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:127
#   204: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#5}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:127
#   203: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::FunctionNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:227
#   202: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::FunctionNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:666
#   201: tvm::relay::transform::DeviceAwareExprMutator::DeviceAwareVisitExpr_(tvm::relay::FunctionNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:282
#   200: tvm::relay::ExprMutator::VisitExpr_(tvm::relay::FunctionNode const*)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:204
#   199: tvm::relay::ExprMutator::Mutate(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:190
#   198: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   197: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   196: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   195: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   194: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   193: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   192: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   191: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   190: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   189: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   188: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   187: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   186: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   185: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   184: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   183: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   182: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   181: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   180: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   179: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   178: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   177: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   176: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   175: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   174: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   173: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   172: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   171: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   170: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   169: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   168: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   167: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   166: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   165: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   164: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   163: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   162: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   161: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   160: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   159: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   158: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   157: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   156: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   155: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   154: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   153: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   152: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   151: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   150: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   149: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   148: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   147: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   146: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   145: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   144: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   143: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   142: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   141: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   140: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   139: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   138: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   137: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   136: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   135: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   134: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   133: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   132: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   131: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   130: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   129: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   128: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   127: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   126: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   125: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   124: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   123: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   122: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   121: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   120: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   119: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   118: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   117: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   116: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   115: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   114: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   113: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   112: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   111: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   110: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   109: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   108: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   107: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   106: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   105: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   104: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   103: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   102: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   101: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   100: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   99: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   98: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   97: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   96: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   95: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   94: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   93: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   92: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   91: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   90: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   89: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   88: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   87: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   86: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   85: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   84: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   83: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   82: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   81: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   80: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   79: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
# ...
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   60: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   59: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   58: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   57: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   56: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   55: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   54: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   53: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   52: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   51: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   50: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   49: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   48: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   47: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   46: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   45: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   44: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   43: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   42: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   41: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#10}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:132
#   40: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#10}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:132
#   39: tvm::relay::ExprMutator::VisitExpr_(tvm::relay::TupleGetItemNode const*)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:249
#   38: tvm::relay::ExprMutator::Mutate(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:190
#   37: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   36: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   35: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   34: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   33: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   32: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   31: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   30: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   29: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   28: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   27: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   26: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   25: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   24: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:701
#   23: tvm::relay::ExprMutator::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/src/relay/ir/expr_functor.cc:158
#   22: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::VisitExpr(tvm::RelayExpr const&)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:95
#   21: tvm::NodeFunctor<tvm::RelayExpr (tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)>::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/node/functor.h:97
#   20: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::__invoke(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   19: tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>::InitVTable()::{lambda(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*)#6}::operator()(tvm::runtime::ObjectRef const&, tvm::relay::ExprFunctor<tvm::RelayExpr (tvm::RelayExpr const&)>*) const
#         at /home/yuheng/tvm/include/tvm/relay/expr_functor.h:128
#   18: tvm::relay::transform::DeviceAwareExprMutator::VisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/transforms/device_aware_visitors.cc:277
#   17: tvm::relay::tec::LowerTensorExprMutator::DeviceAwareVisitExpr_(tvm::relay::CallNode const*)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:757
#   16: tvm::relay::tec::LowerTensorExprMutator::MakeLoweredCall(tvm::relay::Function, tvm::runtime::Array<tvm::RelayExpr, void>, tvm::runtime::Array<tvm::Type, void>, tvm::Span, tvm::Target)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:566
#   15: tvm::relay::tec::TECompilerImpl::Lower(tvm::relay::tec::CCacheKey const&, tvm::runtime::String)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:83
#   14: tvm::relay::tec::TECompilerImpl::Lower(tvm::relay::tec::CCacheKey const&, std::function<tvm::runtime::String (tvm::runtime::String)>)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:77
#   13: tvm::relay::tec::TECompilerImpl::LowerInternal(tvm::relay::tec::CCacheKey const&, std::function<tvm::runtime::String (tvm::runtime::String)>)
#         at /home/yuheng/tvm/src/relay/backend/te_compiler.cc:330
#   12: tvm::LowerSchedule(tvm::te::Schedule, tvm::runtime::Array<tvm::te::Tensor, void> const&, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, std::unordered_map<tvm::te::Tensor, tvm::tir::Buffer, std::hash<tvm::te::Tensor>, std::equal_to<tvm::te::Tensor>, std::allocator<std::pair<tvm::te::Tensor const, tvm::tir::Buffer> > > const&, bool)
#         at /home/yuheng/tvm/src/driver/driver_api.cc:378
#   11: tvm::LowerSchedule(tvm::te::Schedule, tvm::runtime::Array<tvm::runtime::ObjectRef, void> const&, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, std::unordered_map<tvm::te::Tensor, tvm::tir::Buffer, std::hash<tvm::te::Tensor>, std::equal_to<tvm::te::Tensor>, std::allocator<std::pair<tvm::te::Tensor const, tvm::tir::Buffer> > > const&, bool)
#         at /home/yuheng/tvm/src/driver/driver_api.cc:383
#   10: tvm::ScheduleToModule(tvm::te::Schedule, tvm::runtime::Array<tvm::runtime::ObjectRef, void> const&, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, std::unordered_map<tvm::te::Tensor, tvm::tir::Buffer, std::hash<tvm::te::Tensor>, std::equal_to<tvm::te::Tensor>, std::allocator<std::pair<tvm::te::Tensor const, tvm::tir::Buffer> > > const&)
#         at /home/yuheng/tvm/src/driver/driver_api.cc:305
#   9: tvm::te::ScheduleOps(tvm::te::Schedule, tvm::runtime::Map<tvm::tir::IterVar, tvm::Range, void, void>, bool)
#         at /home/yuheng/tvm/src/te/schedule/schedule_ops.cc:366
#   8: tvm::te::MakePipeline(tvm::te::Stage const&, std::unordered_map<tvm::tir::IterVar, tvm::Range, std::hash<tvm::tir::IterVar>, std::equal_to<tvm::tir::IterVar>, std::allocator<std::pair<tvm::tir::IterVar const, tvm::Range> > > const&, tvm::tir::Stmt, bool)
#         at /home/yuheng/tvm/src/te/schedule/schedule_ops.cc:45
#   7: tvm::te::ComputeOpNode::BuildProvide(tvm::te::Stage const&, std::unordered_map<tvm::tir::IterVar, tvm::Range, std::hash<tvm::tir::IterVar>, std::equal_to<tvm::tir::IterVar>, std::allocator<std::pair<tvm::tir::IterVar const, tvm::Range> > > const&, bool) const
#         at /home/yuheng/tvm/src/te/operation/compute_op.cc:434
#   6: tvm::te::MakeComputeStmt(tvm::te::ComputeOpNode const*, tvm::te::Stage const&, std::unordered_map<tvm::tir::IterVar, tvm::Range, std::hash<tvm::tir::IterVar>, std::equal_to<tvm::tir::IterVar>, std::allocator<std::pair<tvm::tir::IterVar const, tvm::Range> > > const&, bool)
#         at /home/yuheng/tvm/src/te/operation/compute_op.cc:345
#   5: tvm::te::ComputeLoopNest::Create(tvm::te::BaseComputeOpNode const*, tvm::te::Stage const&, std::unordered_map<tvm::tir::IterVar, tvm::Range, std::hash<tvm::tir::IterVar>, std::equal_to<tvm::tir::IterVar>, std::allocator<std::pair<tvm::tir::IterVar const, tvm::Range> > > const&, bool)
#         at /home/yuheng/tvm/src/te/operation/compute_op.cc:444
#   4: tvm::te::MakeLoopNest(tvm::te::Stage const&, std::unordered_map<tvm::tir::IterVar, tvm::Range, std::hash<tvm::tir::IterVar>, std::equal_to<tvm::tir::IterVar>, std::allocator<std::pair<tvm::tir::IterVar const, tvm::Range> > > const&, unsigned long, bool, std::unordered_set<tvm::tir::IterVar, std::hash<tvm::tir::IterVar>, std::equal_to<tvm::tir::IterVar>, std::allocator<tvm::tir::IterVar> > const&, std::unordered_map<tvm::tir::IterVar, tvm::PrimExpr, std::hash<tvm::tir::IterVar>, std::equal_to<tvm::tir::IterVar>, std::allocator<std::pair<tvm::tir::IterVar const, tvm::PrimExpr> > >*, bool)
#         at /home/yuheng/tvm/src/te/operation/op_utils.cc:189
#   3: tvm::te::PassUpIndex(tvm::te::Stage const&, tvm::runtime::Map<tvm::tir::IterVar, tvm::Range, void, void> const&, std::unordered_map<tvm::tir::IterVar, tvm::PrimExpr, std::hash<tvm::tir::IterVar>, std::equal_to<tvm::tir::IterVar>, std::allocator<std::pair<tvm::tir::IterVar const, tvm::PrimExpr> > >*, bool)
#         at /home/yuheng/tvm/src/te/schedule/message_passing.cc:201
#   2: tvm::indexdiv(tvm::PrimExpr, tvm::PrimExpr, tvm::Span)
#         at /home/yuheng/tvm/src/tir/op/op.cc:370
#   1: tvm::floordiv(tvm::PrimExpr, tvm::PrimExpr, tvm::Span)
#         at /home/yuheng/tvm/src/tir/op/op.cc:378
#   0: tvm::PrimExpr tvm::arith::TryConstFold<tvm::tir::FloorDiv>(tvm::PrimExpr, tvm::PrimExpr)
#         at /home/yuheng/tvm/src/tir/op/../../arith/const_fold.h:196
#   File "/home/yuheng/tvm/src/arith/const_fold.h", line 207
# TVMError:
# ---------------------------------------------------------------
# An error occurred during the execution of TVM.
# For more information, please see: https://tvm.apache.org/docs/errors.html
# ---------------------------------------------------------------
#
#   Check failed: pb->value != 0 (0 vs. 0) : Divide by zero

# %%
temp.recorder[-7]
# Out:
# [array([  6, 143, 163, 366,  71]),
#  (False,
#   tvm._ffi.base.TVMError('Traceback (most recent call last):\n  251: TVMFuncCall\n        at /home/yuheng/tvm/src/runtime/c_runtime_api.cc:474\n  250: tvm::runtime::PackedFunc::CallPacked(tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*) const\n        at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1151\n  249: std::function<void (tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*)>::operator()(tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*) const\n        at /usr/bin/../lib/gcc/x86_64-linux-gnu/9/../../../../include/c++/9/bits/std_function.h:688\n  248: std::_Function_handler<void (tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*), tvm::relay::backend::RelayBuildModule::GetFunction(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, tvm::runtime::ObjectPtr<tvm::runtime::Object> const&)::{lambda(tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*)#3}>::_M_invoke(std::_Any_data const&, tvm::runtime::TVMArgs&&, tvm::runtime::TVMRetValue*&&)\n        at /usr/bin/../lib/gcc/x86_64-linux-gnu/9/../../../../include/c++/9/bits/std_function.h:300\n  247: tvm::relay::backend::RelayBuildModule::GetFunction(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, tvm::runtime::ObjectPtr<tvm::runtime::Object> const&)::{lambda(tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*)#3}::operator()(tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*) const\n        at /home/yuheng/tvm/src/relay/backend/build_module.cc:190\n  246: tvm::relay::backend::RelayBuildModule::Build(tvm::IRModule, tvm::runtime::Map<tvm::Integer, tvm::Target, void, void> const&, tvm::Target const&, tvm::relay::Executor const&, tvm::relay::Runtime const&, tvm::runtime::String)\n        at /home/yuheng/tvm/src/relay/backend/build_module.cc:303\n  245: tvm::relay::backend::RelayBuildModule::BuildRelay(tvm::IRModule, tvm::runtime::String const&)\n        at /home/yuheng/tvm/src/relay/backend/build_module.cc:415\n  244: tvm::relay::backend::ExecutorCodegen::Codegen(tvm::IRModule, tvm::relay::Function const&, tvm::runtime::String)\n        at /home/yuheng/tvm/src/relay/backend/build_module.cc:65\n  243: void tvm::relay::backend::ExecutorCodegen::CallFunc<tvm::IRModule, tvm::relay::Function, tvm::runtime::String>(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, tvm::IRModule, tvm::relay::Function, tvm::runtime::String)\n        at /home/yuheng/tvm/src/relay/backend/build_module.cc:119\n  242: tvm::runtime::TVMRetValue tvm::runtime::PackedFunc::operator()<tvm::IRModule, tvm::relay::Function, tvm::runtime::String>(tvm::IRModule&&, tvm::relay::Function&&, tvm::runtime::String&&) const\n        at /home/yuheng/tvm/include/tvm/runtime/packed_func.h:1369\n  241: std::function<void (tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*)>::operator()(tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*) const\n        at /usr/bin/../lib/gcc/x86_64-linux-gnu/9/../../../../include/c++/9/bits/std_function.h:688\n  240: std::_Function_handler<void (tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*), tvm::relay::backend::GraphExecutorCodegenModule::GetFunction(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, tvm::runtime::ObjectPtr<tvm::runtime::Object> const&)::{lambda(tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*)#2}>::_M_invoke(std::_Any_data const&, tvm::runtime::TVMArgs&&, tvm::runtime::TVMRetValue*&&)\n        at /usr/bin/../lib/gcc/x86_64-linux-gnu/9/../../../../include/c++/9/bits/std_function.h:300\n  239: tvm::relay::backend::GraphExecutorCodegenModule::GetFunction(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, tvm::runtime::ObjectPtr<tvm::runtime::Object> const&)::{lambda(tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*)#2}::operator()(tvm::runtime::TVMArgs, tvm::runtime::TVMRetValue*) const\n        at /home/yuheng/tvm/src/relay/backend/graph_executor_codegen.cc:661\n  238: tvm::relay::backend:: ...
#   None)]

# %%
# AssertionError: only support 2-dim log softmax
